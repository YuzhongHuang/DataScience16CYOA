# %% [markdown]
# <p>
#     Goal: To visualize and describe the Kaggle Sentiment Anaylsis on Movie Reviews DataSet
# </p>

# %%
#load the data
import pandas as pd
import matplotlib.pyplot as plt
import string
import pickle
import math
# %matplotlib inline

#import all necessary libraries
train_df = pd.read_table('train.tsv', header=0)
print train_df
print(train_df.describe())
print(train_df.columns)
# Out:
#         PhraseId  SentenceId  \
# 0              1           1
# 1              2           1
# 2              3           1
# 3              4           1
# 4              5           1
# 5              6           1
# 6              7           1
# 7              8           1
# 8              9           1
# 9             10           1
# 10            11           1
# 11            12           1
# 12            13           1
# 13            14           1
# 14            15           1
# 15            16           1
# 16            17           1
# 17            18           1
# 18            19           1
# 19            20           1
# 20            21           1
# 21            22           1
# 22            23           1
# 23            24           1
# 24            25           1
# 25            26           1
# 26            27           1
# 27            28           1
# 28            29           1
# 29            30           1
# ...          ...         ...
# ...

# %% [markdown]
# <p>
# Let's start by looking at the independant data for each sentiment and separating the data into 4 splits.
# </p>

# %%
train_1 = train_df[train_df['Sentiment'] == 1]
train_2 = train_df[train_df['Sentiment'] == 2]
train_3 = train_df[train_df['Sentiment'] == 3]
train_4 = train_df[train_df['Sentiment'] == 4]
#print train_1.describe()
#print train_2.describe()
#print train_3.describe()
#print train_4.describe()
#Let's create some features about each sentence and see what are the most common words not articles for each sentiment'

print train_1['Phrase']
def process_line(line,hist):
    """
        Taken from ThinkPython book, takes a line, strips it, updates histogram
        inputs: a line and histogram object
        returns: none
    """
    line = line.replace('-', ' ')
    for word in line.split():
        word = word.strip(string.punctuation + string.whitespace)
        word = word.lower()
        hist[word] = hist.get(word, 0) +1
def pull_unique_word_count(df):
    #Takes each word from the phrase category and returns a histogram of the unique words
    hist = dict()
    for row in df.iterrows():
        sentence = df['Phrase'][row]
        process_line(sentence,hist)
    return hist
print len(train_1)      
print train_1['Phrase'][0]
#print pull_unique_word_count(train_1)
data = pull_unique_word_count(train_1)
type(data)
# Out:
# 0         A series of escapades demonstrating the adage ...
# 33        the gander , some of which occasionally amuses...
# 47             but none of which amounts to much of a story
# 49                 none of which amounts to much of a story
# 81        Even fans of Ismail Merchant 's work , I suspe...
# 94        , I suspect , would have a hard time sitting t...
# 100       would have a hard time sitting through this one .
# 105                    a hard time sitting through this one
# 106                                             a hard time
# 107                                               hard time
# 110                                sitting through this one
# 131             the intrigue , betrayal , deceit and murder
# 135                            betrayal , deceit and murder
# 137                                     , deceit and murder
# 138                                       deceit and murder
# 140                                                  deceit
# ...
